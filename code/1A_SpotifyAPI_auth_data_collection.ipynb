# %% [markdown]
# ### **Spotify Authorization and Calls to API**

# %% [markdown]
# #### **Imports**

# %%
import pandas as pd
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import numpy as np

# %%
# credentials
client_id = 'YOUR CLIENT ID'
client_secret = 'YOUR CLIENT SECRET'
redirect_url = 'YOUR REDIRECT URL'
user_id = 'YOUR USER ID'

# scopes to use for authorization when getting user data
scope_playlist = 'playlist-read-private'
scope_user = 'user-library-read'
scope_user_modify = 'user-library-modify'

# authorization for getting data - no user
global_auth_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=global_auth_manager)

# authorization for getting user data
user_auth_manager = SpotifyOAuth(scope=scope_playlist,client_id=client_id,client_secret=client_secret,username=user_id, redirect_uri=redirect_url)
sp = spotipy.Spotify(auth_manager=user_auth_manager, requests_timeout=120)

# %% [markdown]
# #### **Get list of track ID's in a playlist using playlist ID's**

# %%
def spotify_api_playlist(playlist_id):
    
    # user credentials
    client_id = YOUR CLIENT ID'
    client_secret = 'YOUR CLIENT SECRET'
    redirect_url = 'YOUR REDIRECT URL'
    user_id = 'YOUR USER ID'
    scope_playlist = 'playlist-read-private'
    
    # get user authorization
    user_auth_manager = SpotifyOAuth(scope=scope_playlist,client_id=client_id,client_secret=client_secret,username=user_id, redirect_uri=redirect_url)
    sp = spotipy.Spotify(auth_manager=user_auth_manager)
    
    # get list of track ids in playlist
    playlist = sp.playlist_tracks(playlist_id)
    song_ids = []
    for result in playlist['tracks']['items']:
        song_ids.append(result['track']['id'])
    return song_ids

# %% [markdown]
# #### **Method for Mood Labeling**

# %%
mood_list = []
for i in (sp.categories(limit=50)['categories']['items']):
    if i['name'] == 'Mood':
        category_mood_id = i['id']
mood_playlists = []
mood_playlists_2 = []
for i in sp.category_playlists(category_id = category_mood_id, limit=50)['playlists']['items']:
    description = i['description']
    name = i['name']
    playlist_id = i['id']
    mood_playlists.append(playlist_id)
    mood_playlists_2.append([playlist_id, name, description])

# %%
df_mood = pd.DataFrame(mood_playlists_2, columns = ['playlist_id','name','description'])
df_mood.head()
# Out:
#               playlist_id                         name  \
# 0  37i9dQZF1DX3rxVfibe1L0                 Mood Booster
# 1  37i9dQZF1DX6GwdWRQMQpq               Feelin' Myself
# 2  37i9dQZF1DXcSzYlwgjiSi                   Party Cove
# 3  37i9dQZF1DX4OzrY981I1W           my life is a movie
# 4  37i9dQZF1DWSqmBTGDYngZ  Songs to Sing in the Shower
#
#                                          description
# 0    Get happy with today's dose of feel-good songs!
# 1  The hip-hop playlist that's a whole mood. Cove...
# 2    The perfect soundtrack for a day on the water.
# 3        every main character needs their soundtrack
# 4  Make your shower more uplifting by singing alo...

# %% [markdown]
# #### **50 playlists**

# %%
df_mood.shape
# Out:
# (50, 3)

# %%
[x for x in df_mood['name']]
# Out:
# ['Mood Booster',
#  "Feelin' Myself",
#  'Party Cove',
#  'my life is a movie',
#  'Songs to Sing in the Shower',
#  'BBE',
#  'Energy Booster: Hip-Hop',
#  'Have a Great Day!',
#  'Good Vibes',
#  'Energy Booster: Country',
#  'sad hour',
#  'Happy Hits!',
#  'Happy Beats',
#  'Gameday',
#  'All The Feels',
#  'Taste',
#  'Confidence Boost',
#  "Feelin' Good",
#  'aesthetic',
#  'Get Chores Done',
#  'DOPAMINE',
#  'Chill Tracks',
#  'Your Favorite Coffeehouse',
#  'Cleaning Kit',
#  'Feel-Good Indie Rock',
#  'Wake Up Happy',
#  'Jazz Vibes',
#  'Morning Coffee',
#  'Energy Booster: Pop',
#  'tear drop',
#  'idk.',
#  'park hangs',
#  'Life Sucks',
#  'Low-Key',
#  'Beach Vibes',
#  'Trophy Room',
#  'y2k',
#  'Good Times, Great Oldies',
#  "It's ALT Good!",
#  'Work From Home',
#  'young & free',
#  'Wake Up Gently',
#  'Alone Again',
#  '2 . 24',
#  'Chilled R&B',
#  'Surf Rock Sunshine',
#  'text me back',
#  'pumpkin spice',
#  'Energy Booster: R&B',
#  'songs to scream in the car']

# %% [markdown]
# ##### Create dictionary for playlist mood label

# %%
mood_dict = {
     'Mood Booster'                : 'happy',
     "Feelin' Myself"              : 'energetic',
     'Party Cove'                  : 'energetic',
     'my life is a movie'          : 'sad',
     'Songs to Sing in the Shower' : 'happy',
     'BBE'                         : 'energetic',
     'Have a Great Day!'           : 'happy',
     'Energy Booster: Hip-Hop'     : 'energetic',
     'sad hour'                    : 'sad',
     'Good Vibes'                  : 'happy',
     'Energy Booster: Country'     : 'energetic',
     'Happy Hits!'                 : 'happy',
     'All The Feels'               : 'sad',
     "Feelin' Good"                : 'happy',
     'Confidence Boost'            : 'energetic',
     'aesthetic'                   : 'calm',
     'Happy Beats'                 : 'happy',
     'DOPAMINE'                    : 'energetic',
     'Your Favorite Coffeehouse'   : 'calm',
     'Chill Tracks'                : 'calm',
     'Wake Up Happy'               : 'happy',
     'Get Chores Done'             : 'calm',
     'Jazz Vibes'                  : 'calm',
     'Feel-Good Indie Rock'        : 'calm',
     'Morning Coffee'              : 'calm',
     'Taste'                       : 'energetic',
     'Work From Home'              : 'calm',
     'Wake Up Gently'              : 'calm',
     'Energy Booster: Pop'         : 'energetic',
     'park hangs'                  : 'calm',
     'Life Sucks'                  : 'sad',
     'Ready for the Day'           : 'calm',
     'tear drop'                   : 'sad',
     'Gameday'                     : 'energetic',
     'idk.'                        : 'sad',
     'Cleaning Kit'                : 'happy',
     'Low-Key'                     : 'calm',
     'Brain Food'                  : 'calm',
     'y2k'                         : 'energetic',
     "It's ALT Good!"              : 'happy',
     'Trophy Room'                 : 'energetic',
     'Alone Again'                 : 'sad',
     'Beach Vibes'                 : 'calm',
     'A Perfect Day'               : 'happy',
     'young & free'                : 'energetic',
     'pumpkin spice'               : 'sad',
     'text me back'                : 'sad',
     'wanderlust'                  : 'sad',
     'Good Times, Great Oldies'    : 'calm',
     'songs to scream in the car'  : 'happy'
}

# %%
df_mood['mood'] = df_mood['name'].map(mood_dict)
df_mood.head(10)
# Out:
#               playlist_id                         name  \
# 0  37i9dQZF1DX3rxVfibe1L0                 Mood Booster
# 1  37i9dQZF1DX6GwdWRQMQpq               Feelin' Myself
# 2  37i9dQZF1DXcSzYlwgjiSi                   Party Cove
# 3  37i9dQZF1DX4OzrY981I1W           my life is a movie
# 4  37i9dQZF1DWSqmBTGDYngZ  Songs to Sing in the Shower
# 5  37i9dQZF1DX66m4icL86Ru                          BBE
# 6  37i9dQZF1DWZixSclZdoFE      Energy Booster: Hip-Hop
# 7  37i9dQZF1DX7KNKjOK0o75            Have a Great Day!
# 8  37i9dQZF1DWYBO1MoTDhZI                   Good Vibes
# 9  37i9dQZF1DWXLSRKeL7KwM      Energy Booster: Country
#
#                                          description       mood
# 0    Get happy with today's dose of feel-good songs!      happy
# 1  The hip-hop playlist that's a whole mood. Cove...  energetic
# 2    The perfect soundtrack for a day on the water.   energetic
# 3        every main character needs their soundtrack        sad
# 4  Make your shower more uplifting by singing alo...      happy
# 5  Bad b**** energy. Be blessed, be spicy. Cover:...  energetic
# 6  Need to get your energy level up? This will help!  energetic
# 7        Feel great with these timelessly fun songs!      happy
# 8  Set it off with these epic anthems. Only good ...      happy
# 9  Need to get your energy level up? This will help!  energetic

# %%
df_mood.shape
# Out:
# (50, 4)

# %%
df_mood['mood'].fillna(value='energetic', limit=1, inplace=True)
df_mood['mood'].fillna(value='calm', limit=2, inplace=True)
df_mood['mood'].fillna(value='energetic', inplace=True)

# %%
df_mood.isna().sum()
# Out:
# playlist_id    0
# name           0
# description    0
# mood           0
# dtype: int64

# %%
# [x for x in df_mood['playlist_id'] if .
df_mood['mood'].value_counts()
# Out:
# calm         15
# energetic    15
# happy        11
# sad           9
# Name: mood, dtype: int64

# %%
happy_list=[x for x in df_mood[df_mood['mood'] == 'happy']['playlist_id']]
sad_list=[x for x in df_mood[df_mood['mood'] == 'sad']['playlist_id']]
calm_list=[x for x in df_mood[df_mood['mood'] == 'calm']['playlist_id']]
energetic_list=[x for x in df_mood[df_mood['mood'] == 'energetic']['playlist_id']]

# %% [markdown]
# ##### Function to get track IDs of each track in a list of playlist IDs
# ###### Returns list of track IDs

# %%
def spotify_multi_playlists_tracks(playlist_ids):
    playlist_trackID_list = {}
    song_ids = []
    
    for playlist in playlist_ids:
        playlist_tracks = sp.playlist_tracks(playlist)
        
        for result in playlist_tracks['items']:
            track_id = result['track']['id']
            
            song_ids.append(result['track']['id'])
        
    return song_ids

# %%
happy_track_ids=spotify_multi_playlists_tracks(playlist_ids=happy_list)
sad_track_ids=spotify_multi_playlists_tracks(playlist_ids=sad_list)

# %%
calm_track_ids=spotify_multi_playlists_tracks(playlist_ids=calm_list)
energetic_track_ids=spotify_multi_playlists_tracks(playlist_ids=energetic_list)

# %% [markdown]
# ##### Function for obtaining track features for each track in list of track IDs
# ###### Returns list

# %%
def get_audio_features(track_ids):
    
    mood_features_data = []
    
    for track in track_ids:
        mood_audio_features_list = sp.audio_features(tracks=track)

        for feature in mood_audio_features_list:
        
            acousticness = feature['acousticness']
            danceability = feature['danceability']
            energy = feature['energy']
            instrumentalness = feature['instrumentalness']
            liveness = feature['liveness']
            valence = feature['valence']
            loudness = feature['loudness']
            speechiness = feature['speechiness']
            tempo = feature['tempo']
            key = feature['key']
            time_signature = feature['time_signature']
            track_id = feature['id']
            track = sp.track(track_id)
            name = track['name']
            artist = track['artists'][0]['name']
            length = track['duration_ms']
            popularity = track['popularity']
            mood_features_data.append([name, 
                                  artist, 
                                  track_id, 
                                  instrumentalness, 
                                  danceability, 
                                  energy, 
                                  liveness, 
                                  loudness, 
                                  acousticness, 
                                  valence, 
                                  speechiness,
                                  tempo, 
                                  key,
                                  time_signature,
                                  length,
                                  popularity])  
    return mood_features_data

# %%
happy_features=get_audio_features(track_ids=happy_track_ids)

# %%
sad_features=get_audio_features(track_ids=sad_track_ids)

# %%
calm_features=get_audio_features(track_ids=calm_track_ids)

# %%
energetic_features=get_audio_features(track_ids=energetic_track_ids)

# %%
happy = pd.DataFrame(happy_features, columns = ['name', 
                            'artist', 
                            'track_id', 
                            'instrumentalness', 
                            'danceability', 
                            'energy', 
                            'liveness', 
                            'loudness', 
                            'acousticness', 
                            'valence', 
                            'speechiness',
                            'tempo', 
                            'key',
                            'time_signature',
                            'length',
                            'popularity'])
happy['mood'] = ['Happy' for x in happy['name']]
sad = pd.DataFrame(sad_features, columns = ['name', 
                            'artist', 
                            'track_id', 
                            'instrumentalness', 
                            'danceability', 
                            'energy', 
                            'liveness', 
                            'loudness', 
                            'acousticness', 
                            'valence', 
                            'speechiness',
                            'tempo', 
                            'key',
                            'time_signature',
                            'length',
                            'popularity'])
sad['mood'] = ['Sad' for x in sad['name']]
calm = pd.DataFrame(calm_features, columns = ['name', 
                            'artist', 
                            'track_id', 
                            'instrumentalness', 
                            'danceability', 
                            'energy', 
                            'liveness', 
                            'loudness', 
                            'acousticness', 
                            'valence', 
                            'speechiness',
                            'tempo', 
                            'key',
                            'time_signature',
                            'length',
                            'popularity'])
calm['mood'] = ['Calm' for x in calm['name']]
energetic = pd.DataFrame(energetic_features, columns = ['name', 
                            'artist', 
                            'track_id', 
                            'instrumentalness', 
                            'danceability', 
                            'energy', 
                            'liveness', 
                            'loudness', 
                            'acousticness', 
                            'valence', 
                            'speechiness',
                            'tempo', 
                            'key',
                            'time_signature',
                            'length',
                            'popularity'])
energetic['mood'] = ['Energetic' for x in energetic['name']]

# %%
df=pd.concat([happy, sad, energetic, calm])
df.head()
# Out:
#                        name         artist                track_id  \
# 0  Kiss Me More (feat. SZA)       Doja Cat  748mdHapucXQri7IAO8yFK
# 1              seaside_demo            SEB  73M0rMVx5CWE8M4uATSsto
# 2                   Shivers     Ed Sheeran  6bQfNiqyCX7UaQSvVVGo4I
# 3                Heat Waves  Glass Animals  02MWAaffLxlfxAUY7c5dvx
# 4             Electric Love          BØRNS  2GiJYvgVaD2HtM8GqD9EgQ
#
#    instrumentalness  danceability  energy  liveness  loudness  acousticness  \
# 0          0.000158         0.762   0.701    0.1230    -3.541       0.23500
# 1          0.000133         0.706   0.824    0.1110    -7.959       0.35500
# 2          0.000000         0.788   0.859    0.0424    -2.724       0.28100
# 3          0.000007         0.761   0.525    0.0921    -6.900       0.44000
# 4          0.001370         0.611   0.797    0.2600    -7.627       0.00543
#
#    valence  speechiness    tempo  key  time_signature  length  popularity  \
# 0    0.742       0.0286  110.968    8               4  208866          92
# 1    0.860       0.0694   94.980    0               4  132000          54
# 2    0.822       0.0856  141.020    2               4  207853          78
# 3    0.531       0.0944   80.870   11               4  238805          85
# 4    0.518       0.0533  120.041    6               4  218106          82
#
#     mood
# 0  Happy
# 1  Happy
# 2  Happy
# 3  Happy
# 4  Happy

# %%
df.to_csv('../data/mood_df.csv', index=False)

# %%
df.isna().sum()
# Out:
# name                0
# artist              0
# track_id            0
# instrumentalness    0
# danceability        0
# energy              0
# liveness            0
# loudness            0
# acousticness        0
# valence             0
# speechiness         0
# tempo               0
# key                 0
# time_signature      0
# length              0
# popularity          0
# mood                0
# dtype: int64

# %%
df['mood'].value_counts(normalize=True)
# Out:
# Calm         0.296002
# Energetic    0.266542
# Happy        0.242226
# Sad          0.195230
# Name: mood, dtype: float64

# %% [markdown]
# ##### **Adding 'Sad' playlists manually**

# %%
extra_sad=['37i9dQZF1DWT0RWUaj5iTz?si=1e118b2744d64e2a',
             '37i9dQZF1DX7qK8ma5wgG1?si=3dad9750486c4eb4',
             '37i9dQZF1DWVV27DiNWxkR?si=ca9e8061769f44c0',
             '4yXfnhz0BReoVfwwYRtPBm?si=61a64faddc2f4fca']

# %%
def get_tracks(playlist_ids):
    for i in playlist_ids:
    # get list of track ids in playlist
        playlist = sp.playlist_tracks(i)
        song_ids = []
        for result in playlist['tracks']['items']:
            song_ids.append(result['track']['id'])
    return song_ids

# %%
ex_sad_list=get_tracks(extra_sad)

# %%
ex_sad_features=get_audio_features(ex_sad_list)

# %%
ex_sad=pd.DataFrame(ex_sad_features, columns = ['name', 
                            'artist', 
                            'track_id', 
                            'instrumentalness', 
                            'danceability', 
                            'energy', 
                            'liveness', 
                            'loudness', 
                            'acousticness', 
                            'valence', 
                            'speechiness',
                            'tempo', 
                            'key',
                            'time_signature',
                            'length',
                            'popularity'])
ex_sad['mood'] = ['Sad' for x in ex_sad['name']]

# %%
df=pd.concat([df, ex_sad])
df.head()
# Out:
#                        name         artist                track_id  \
# 0  Kiss Me More (feat. SZA)       Doja Cat  748mdHapucXQri7IAO8yFK
# 1              seaside_demo            SEB  73M0rMVx5CWE8M4uATSsto
# 2                   Shivers     Ed Sheeran  6bQfNiqyCX7UaQSvVVGo4I
# 3                Heat Waves  Glass Animals  02MWAaffLxlfxAUY7c5dvx
# 4             Electric Love          BØRNS  2GiJYvgVaD2HtM8GqD9EgQ
#
#    instrumentalness  danceability  energy  liveness  loudness  acousticness  \
# 0          0.000158         0.762   0.701    0.1230    -3.541       0.23500
# 1          0.000133         0.706   0.824    0.1110    -7.959       0.35500
# 2          0.000000         0.788   0.859    0.0424    -2.724       0.28100
# 3          0.000007         0.761   0.525    0.0921    -6.900       0.44000
# 4          0.001370         0.611   0.797    0.2600    -7.627       0.00543
#
#    valence  speechiness    tempo  key  time_signature  length  popularity  \
# 0    0.742       0.0286  110.968    8               4  208866          92
# 1    0.860       0.0694   94.980    0               4  132000          54
# 2    0.822       0.0856  141.020    2               4  207853          78
# 3    0.531       0.0944   80.870   11               4  238805          85
# 4    0.518       0.0533  120.041    6               4  218106          82
#
#     mood
# 0  Happy
# 1  Happy
# 2  Happy
# 3  Happy
# 4  Happy

# %%
df.shape
# Out:
# (4477, 17)

# %%
df['mood'].value_counts(normalize=True)
# Out:
# Calm         0.282779
# Energetic    0.254635
# Happy        0.231405
# Sad          0.231182
# Name: mood, dtype: float64

# %%
df['mood'].isna().sum()
# Out:
# 0

# %%
df.to_csv('../data/mood_df.csv', index=False)

# %%
kaggle = pd.read_csv('../data/data_moods.csv')
kaggle.head()
# Out:
#                                           name                        album  \
# 0                                         1999                         1999
# 1                                           23                           23
# 2                                     9 Crimes                            9
# 3                               99 Luftballons               99 Luftballons
# 4  A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
#
#            artist                      id release_date  popularity  length  \
# 0          Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266
# 1  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800
# 2     Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06          60  217946
# 3            Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21           2  233000
# 4       Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000
#
#    danceability  acousticness  energy  instrumentalness  liveness  valence  \
# 0         0.866       0.13700   0.730          0.000000    0.0843    0.625
# 1         0.381       0.01890   0.832          0.196000    0.1530    0.166
# 2         0.346       0.91300   0.139          0.000077    0.0934    0.116
# 3         0.466       0.08900   0.438          0.000006    0.1130    0.587
# 4         0.419       0.00171   0.932          0.000000    0.1370    0.445
#
#    loudness  speechiness    tempo  key  time_signature       mood
# 0    -8.201       0.0767  118.523    5               4      Happy
# 1    -5.069       0.0492  120.255    8               4        Sad
# 2   -15.326       0.0321  136.168    0               4        Sad
# 3   -12.858       0.0608  193.100    4               4      Happy
# 4    -3.604       0.1060  169.881    1               4  Energetic

# %%
kaggle.rename(columns={'id':'track_id'}, inplace=True)
kaggle.drop(columns=['album','release_date'], inplace=True)

# %%
df=pd.concat([df, kaggle])
df.head()
# Out:
#                        name         artist                track_id  \
# 0  Kiss Me More (feat. SZA)       Doja Cat  748mdHapucXQri7IAO8yFK
# 1              seaside_demo            SEB  73M0rMVx5CWE8M4uATSsto
# 2                   Shivers     Ed Sheeran  6bQfNiqyCX7UaQSvVVGo4I
# 3                Heat Waves  Glass Animals  02MWAaffLxlfxAUY7c5dvx
# 4             Electric Love          BØRNS  2GiJYvgVaD2HtM8GqD9EgQ
#
#    instrumentalness  danceability  energy  liveness  loudness  acousticness  \
# 0          0.000158         0.762   0.701    0.1230    -3.541       0.23500
# 1          0.000133         0.706   0.824    0.1110    -7.959       0.35500
# 2          0.000000         0.788   0.859    0.0424    -2.724       0.28100
# 3          0.000007         0.761   0.525    0.0921    -6.900       0.44000
# 4          0.001370         0.611   0.797    0.2600    -7.627       0.00543
#
#    valence  speechiness    tempo  key  time_signature  length  popularity  \
# 0    0.742       0.0286  110.968    8               4  208866          92
# 1    0.860       0.0694   94.980    0               4  132000          54
# 2    0.822       0.0856  141.020    2               4  207853          78
# 3    0.531       0.0944   80.870   11               4  238805          85
# 4    0.518       0.0533  120.041    6               4  218106          82
#
#     mood
# 0  Happy
# 1  Happy
# 2  Happy
# 3  Happy
# 4  Happy

# %%
df.shape
# Out:
# (5849, 17)

# %%
df['mood'].value_counts(normalize=True)
# Out:
# Calm         0.283125
# Energetic    0.247564
# Sad          0.244315
# Happy        0.224996
# Name: mood, dtype: float64

# %%
df.to_csv('../data/mood_data.csv', index=False)

# %% [markdown]
# #### **Get more labeled data but had issue with Spotify timeouts**
# ###### Did not use

# %%
def spotify_api_playlist(playlist_id):
    
    # user credentials
    client_id = 'a71512db396c4f9f9132928928f9ddff'
    client_secret = '66041252b1f44debae39f3e09953dd74'
    redirect_url = 'https://www.google.com'
    user_id = "bsanzone225"
    genius_access_token = "F_FuandD31vRz1yy6nXxXyeK4eNw6fIlFzGN72_PJRgQkhE294AIk3m_jGUHd03E"
    scope_playlist = 'playlist-read-private'
    
    # get user authorization
    user_auth_manager = SpotifyOAuth(scope=scope_playlist,client_id=client_id,client_secret=client_secret,username=user_id, redirect_uri=redirect_url)
    sp = spotipy.Spotify(auth_manager=user_auth_manager, requests_timeout=120)
    
    # get list of track ids in playlist
    playlist = sp.playlist_tracks(playlist_id)
    song_ids = []
    for result in playlist['tracks']['items']:
        song_ids.append(result['track']['id'])
    return song_ids

# %%
category_list = []
for i in (sp.categories(limit=50)['categories']['items']):
    if i['name'] != 'Mood':
        category_list.append(i['id'])
category_playlists_ids = []
for i in category_list:
    playlist_ids = sp.category_playlists(category_id = i, limit=50)
    for result in playlist_ids['playlists']['items']:
        category_playlists_ids.append(result['id'])

# %%
def get_audio_features(playlists_ids):
    
    features_data = []
    
    for playlist in playlists_ids:
        category_audio_features_list = sp.audio_features(tracks=playlist)

        for feature in category_audio_features_list:
            
            acousticness = feature['acousticness']
            danceability = feature['danceability']
            energy = feature['energy']
            instrumentalness = feature['instrumentalness']
            liveness = feature['liveness']
            valence = feature['valence']
            loudness = feature['loudness']
            speechiness = feature['speechiness']
            tempo = feature['tempo']
            key = feature['key']
            time_signature = feature['time_signature']
            track_id = feature['id']
            track = sp.track(track_id)
            name = track['name']
            artist = track['artists'][0]['name']
            length = track['duration_ms']
            popularity = track['popularity']
            features_data.append([name, 
                                  artist, 
                                  track_id, 
                                  instrumentalness, 
                                  danceability, 
                                  energy, 
                                  liveness, 
                                  loudness, 
                                  acousticness, 
                                  valence, 
                                  speechiness,
                                  tempo, 
                                  key,
                                  time_signature,
                                  length,
                                  popularity])  
    return features_data
